# %% [markdown]
# Essay Evaluation, need to evaluate essay text on follwing aspect
#     * Clarity of Thought (LLM) / (Score 0 - 10) / (Structure Output may be in json)
#     * Depth of Analysis  (LLM) / (Score 0 - 10) / (Structure Output may be in json)
#     * Lanaguage quality  (LLM) / (Score 0 - 10) / (Structure Output may be in json)
#
# Text Feedback
# Score 0 to 10
#
# Summary :
# Summarized Feedback
# Average of the score
#
# We shoulf get the stricture output format
#
# We need to user reducer funciton as well
#
# Then need to generate summarized feedback
#
# -- So we need to know follwoing
# Prallel workflow
# Structure output
# Reducer Function
# --------------
# We are also learning to instruct LLM to provide output schema based

# %% [markdown]
# from langgraph.graph import StateGraph, START, END
# from typing import TypedDict
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv
# load_dotenv()

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from pydantic import BaseModel, Field
import operator
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model='gpt-5-mini')

# %%
class EvaluationSchema(TypedDict):
    feedback: str = Field(description="Detailed feedback for the essay")
    score: int = Field(description="Score out of 10", ge=0, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
essay = "Artificial intelligence (AI) is a technology that has been rapidly gaining popularity in India in recent years. From healthcare to education, agriculture to finance, AI is transforming various industries and shaping the future of technology in the country. In this blog post, we will explore the rise of AI in India, its impact on different sectors, government initiatives to support AI, challenges and opportunities, and the future of AI in the country.\n\nI. Introduction\n\nA. Artificial intelligence (AI) is a branch of computer science that aims to create intelligent machines that can perform tasks that typically require human intelligence.\nB. AI is gaining popularity in India due to advancements in technology, increasing digitalization, and the growing demand for automation and efficiency.\nC. Thesis statement: The rise of AI in India is transforming various industries and shaping the future of technology in the country.\n\nII. History of AI in India\n\nA. Early developments in AI technology in India can be traced back to the 1980s, with the establishment of research institutes and academic programs dedicated to AI.\nB. Key milestones in the adoption of AI in India include the development of AI-powered solutions for different sectors, such as healthcare, finance, and agriculture.\nC. Leading research institutions and organizations contributing to the growth of AI in India include the Indian Institutes of Technology (IITs), Indian Institute of Science (IISc), and corporate research labs like Google Research India.\n\nIII. Impact of AI on Indian Industries\n\nA. Healthcare: AI is being used in medical diagnosis and treatment, as well as in developing personalized healthcare solutions that improve patient care and outcomes.\nB. Education: AI is transforming education through personalized learning, educational technology, and tools that enhance student engagement and performance.\nC. Agriculture: AI is being applied in precision farming, crop management, and addressing challenges in agriculture to increase productivity.\nD. Finance: AI is being used in financial services for fraud detection, risk management, and the development of AI-powered chatbots and virtual assistants to enhance customer service.\n\nIV. Government Initiatives and Policies to Support AI\n\nA. The Indian government has launched a National AI strategy and policies to promote AI innovation and investment in research and development.\nB. The government is investing in AI research and development to support the growth of the AI industry in India.\nC. Collaboration between government, industry, and academia is essential to promote AI innovation and adoption in the country.\n\nV. Challenges and Opportunities in AI Adoption in India\n\nA. Skilled talent shortage in the AI industry is a challenge that needs to be addressed through education and training programs.\nB. Data privacy and security concerns with AI technologies need to be addressed to build trust and ensure responsible AI use.\nC. There are opportunities for Indian startups and entrepreneurs in the AI sector to develop innovative solutions and drive economic growth.\nD. AI has the potential to drive economic growth and job creation in India by enhancing productivity and efficiency in various sectors.\n\nVI. Future of AI in India\n\nA. Predictions for the future growth of AI in India include increased adoption in different sectors and the emergence of new technologies and trends.\nB. Emerging trends and technologies in AI, such as deep learning, reinforcement learning, and natural language processing, will shape the future of Indian industries.\nC. The potential impact of AI on society, economy, and workforce in India includes job displacement, upskilling of the workforce, and the need for regulations to govern AI technologies.\n\nVII. Conclusion\n\nA. The rise of AI in India is transforming various industries and shaping the future of technology in the country.\nB. Readers are encouraged to explore the opportunities and challenges of AI in India and to stay informed about the latest developments in the field.\nC. AI has the transformative power to shape India's future by driving innovation, economic growth, and social change.\n\nIn conclusion, the rise of AI in India is a transformative force that is shaping the future of technology and industries in the country. With the government's support, collaborations between industry and academia, and the growing interest in AI technology, India is well-positioned to capitalize on the opportunities and overcome the challenges that come with the adoption of AI. As AI continues to evolve and impact society, economy, and the workforce in India, it is essential to stay informed, explore the possibilities, and embrace the transformative power of AI to drive innovation and growth in the country."

# %%
prompt = f"Evaluate the language quality of the follwing essay and provide a feedback and assign a score out of 10 \n{essay}"

structured_model.invoke(prompt)
# Out:
# {'feedback': 'Overall assessment: The essay is clear, well-organized, and covers the main points about AI in India (history, sectoral impact, government action, challenges, and future). Its strengths are the logical structure, comprehensive topic coverage, and appropriate formal tone. However, the piece reads more like an extended outline than a polished essay. Language issues and improvement areas:\n\n1) Repetition and redundancy: Many sentences repeat the same idea (e.g., the thesis and conclusion repeatedly restate “AI is transforming industries”). Consolidate and avoid restating identical points.\n2) Lack of concrete examples and evidence: The essay relies on general statements. Add specific examples, case studies, or statistics (for instance, notable Indian AI startups, pilot projects in healthcare/agriculture, or government program names and dates) to make claims persuasive.\n3) Style and flow: The current outline-style headings and short bullet-like sentences interrupt narrati
# ...

# %%
class UPSCSTate(TypedDict):
    essay: str
    language_feedback: str
    analyasis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    average_score: float

# %%
def evaluate_language(state: UPSCSTate) -> UPSCSTate:
    prompt = f"Evaluate the language quality of the follwing essay and provide a feedback and assign a score out of 10 \n{state['essay']}"
    result = structured_model.invoke(prompt)
    language_feedback = result['feedback']
    individual_scores = result['score']
    return {'language_feedback': language_feedback, 'individual_scores': [individual_scores]}

def evaluate_analysis(state: UPSCSTate) -> UPSCSTate:
    prompt = f"Evaluate the depth of analysis of the follwing essay and provide a feedback and assign a score out of 10 \n{state['essay']}"
    result = structured_model.invoke(prompt)
    analyasis_feedback = result['feedback']
    individual_scores = result['score']
    return {'analyasis_feedback': analyasis_feedback, 'individual_scores': [individual_scores]}

def evaluate_thought(state: UPSCSTate) -> UPSCSTate:
    prompt = f"Evaluate the clarity of thought of the follwing essay and provide a feedback and assign a score out of 10 \n{state['essay']}"
    result = structured_model.invoke(prompt)
    clarity_feedback = result['feedback']
    individual_scores = result['score']
    return {'clarity_feedback': clarity_feedback, 'individual_scores': [individual_scores]}

def final_evaluation(state: UPSCSTate) -> UPSCSTate:
    # get over all feedback based on the three feedbacks
    prompt = f"Based on the following feedbackscreate a summarised feedback \n language feedback - {state["language_feedback"]} \n depeth of analysis - {state['analyasis_feedback']} \n clarity of thought - {state['clarity_feedback']}"
    overall_feedback = model.invoke(prompt).content

    # Calculate average score
    average_score = sum(state['individual_scores']) / len(state['individual_scores'])

    return {'overall_feedback': overall_feedback, 'average_score': average_score}

# %%
graph = StateGraph(UPSCSTate)

# Add nodes
graph.add_node("evaluateLanguage", evaluate_language)
graph.add_node("evaluateAnalysis", evaluate_analysis)
graph.add_node("evaluateThought", evaluate_thought)
graph.add_node("finalEvaluation", final_evaluation)

# add edges
graph.add_edge(START, "evaluateLanguage")
graph.add_edge(START, "evaluateAnalysis")
graph.add_edge(START, "evaluateThought")

graph.add_edge("evaluateLanguage", "finalEvaluation")
graph.add_edge("evaluateAnalysis", "finalEvaluation")
graph.add_edge("evaluateThought", "finalEvaluation")

graph.add_edge("finalEvaluation", END)

# Compile
workflow  = graph.compile()

# invoke
initial_state = {
    'essay': essay
}

result = workflow.invoke(initial_state)
print(result)
# Out:
# {'essay': "Artificial intelligence (AI) is a technology that has been rapidly gaining popularity in India in recent years. From healthcare to education, agriculture to finance, AI is transforming various industries and shaping the future of technology in the country. In this blog post, we will explore the rise of AI in India, its impact on different sectors, government initiatives to support AI, challenges and opportunities, and the future of AI in the country.\n\nI. Introduction\n\nA. Artificial intelligence (AI) is a branch of computer science that aims to create intelligent machines that can perform tasks that typically require human intelligence.\nB. AI is gaining popularity in India due to advancements in technology, increasing digitalization, and the growing demand for automation and efficiency.\nC. Thesis statement: The rise of AI in India is transforming various industries and shaping the future of technology in the country.\n\nII. History of AI in India\n\nA. Early developme
# ...
